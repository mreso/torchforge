# %% [markdown]
# # GRPO for Math (GSM8k)
#
# ## Import modules

# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.
# All rights reserved.
#
# This source code is licensed under the BSD-style license found in the
# LICENSE file in the root directory of this source tree.

import asyncio
import time
import uuid
from dataclasses import dataclass
from typing import Any, Callable

import torch
import torch.nn.functional as F
import torchstore as ts
from datasets import load_dataset
from forge.actors._torchstore_utils import (
    get_dcp_whole_state_dict_key,
    get_param_prefix,
)
from forge.actors.generator import Generator as Policy
from forge.actors.reference_model import ReferenceModel
from forge.actors.replay_buffer import ReplayBuffer
from forge.actors.trainer import RLTrainer
from forge.controller.actor import ForgeActor
from forge.controller.provisioner import init_provisioner, shutdown
from forge.data.rewards import MathReward, ThinkingReward
from forge.observability.metric_actors import get_or_create_metric_logger
from forge.observability.metrics import record_metric, Reduce
from forge.observability.perf_tracker import Tracer

from forge.types import LauncherConfig, ProvisionerConfig
from forge.util.ops import compute_logprobs
from monarch.actor import endpoint
from omegaconf import DictConfig
from vllm.transformers_utils.tokenizer import get_tokenizer

import os
os.environ["MONARCH_HOSTMESH_V1"] = "1"
os.environ["TORCHSTORE_RDMA_ENABLED"] = "1"

# %% [markdown]
# ## Define Data Structures

# %%
@dataclass
class Episode:
    # TODO: add adtional layer for multi-turn
    episode_id: str
    request: str
    policy_version: int
    pad_id: int
    request_len: int
    response_len: int
    target: Any | None = None
    # processed data
    response: str | None = None
    request_tokens: list[int] | None = None
    response_tokens: list[int] | None = None
    ref_logprobs: torch.Tensor | None = None
    reward: float | None = None
    advantage: float | None = None

    @property
    def request_tensor(self):
        tensor = torch.tensor(self.request_tokens, dtype=torch.long)
        if tensor.shape[0] < self.request_len:  # left pad
            diff = self.request_len - tensor.shape[0]
            tensor = F.pad(tensor, (diff, 0), value=self.pad_id)
        return tensor

    @property
    def response_tensor(self):
        tensor = torch.tensor(self.response_tokens, dtype=torch.long)
        if tensor.shape[0] < self.response_len:  # right pad
            diff = self.response_len - tensor.shape[0]
            tensor = F.pad(tensor, (0, diff), value=self.pad_id)
        return tensor


@dataclass
class Group:
    group_id: str
    episodes: list[Episode]

    @classmethod
    def new_group(
        cls,
        group_id: int,
        group_size: int,
        request: str,
        policy_version: int,
        pad_id: int,
        request_len: int,
        response_len: int,
        target: Any = None,
    ):
        episodes = []
        for _ in range(group_size):
            episodes.append(
                Episode(
                    episode_id=str(uuid.uuid4()),
                    request=request,
                    policy_version=policy_version,
                    pad_id=pad_id,
                    request_len=request_len,
                    response_len=response_len,
                    target=target,
                )
            )
        return cls(str(group_id), episodes)


def collate(batches: list[list[Episode]]):
    inputs = []
    targets = []
    for batch in batches:
        request = [e.request_tensor for e in batch]
        request = torch.stack(request)  # [b x s]

        response = [e.response_tensor for e in batch]
        response = torch.stack(response)  # [b x s]

        ref_logprobs = [e.ref_logprobs for e in batch]
        ref_logprobs = torch.stack(ref_logprobs).squeeze()  # [b x s]

        advantages = [e.advantage for e in batch]
        advantages = torch.tensor(advantages).unsqueeze(-1)  # [b x 1]

        pad_id = batch[0].pad_id
        mask = response != pad_id

        input = {"tokens": torch.cat([request, response], dim=1)}
        target = {
            "response": response,
            "ref_logprobs": ref_logprobs,
            "advantages": advantages,
            "padding_mask": mask,
        }
        inputs.append(input)
        targets.append(target)
    return inputs, targets

@dataclass
class DatasetActor(ForgeActor):
    """Actor wrapper for HuggingFace dataset to provide async interface."""

    path: str = "openai/gsm8k"
    revision: str = "main"
    data_split: str = "train"
    streaming: bool = True
    model: str = "Qwen/Qwen3-1.7B"

    @endpoint
    def setup(self):
        self._tokenizer = get_tokenizer(self.model)

        def gsm8k_transform(sample):
            system_prompt = """
            Put all your scratchpad work between <think> and </think> tags.
            Your final answer should be between <answer> and </answer> tags otherwise it will not be scored.
            """
            request: str = sample["question"]
            as_chat = [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": request},
            ]
            formatted_request = self._tokenizer.apply_chat_template(
                as_chat,
                tokenize=False,
                add_generation_prompt=True,
            )
            target: str = sample["answer"]
            formatted_target = target.split("#### ")[1]
            return {"request": formatted_request, "target": formatted_target}

        ds = load_dataset(
            self.path, self.revision, split=self.data_split, streaming=self.streaming
        )
        ds = ds.map(gsm8k_transform)
        ds = ds.shuffle()
        self._iterator = iter(ds)

    @endpoint
    async def sample(self) -> dict[str, str] | None:
        try:
            sample = next(self._iterator)

            # Record dataset metrics
            record_metric("dataset/sample/count_samples_generated", 1, Reduce.SUM)
            record_metric(
                "dataset/sample/avg_sample_len",
                len(sample["request"]),
                Reduce.MEAN,
            )

            return sample
        except StopIteration:
            return None

    @endpoint
    async def pad_token(self):
        return self._tokenizer.pad_token_id

# %% [markdown]
# ## Define loss

# %%
def simple_grpo_loss(
    logits: torch.Tensor,
    response: torch.Tensor,
    ref_logprobs: torch.Tensor,
    advantages: torch.Tensor,
    padding_mask: torch.Tensor,
    beta: float = 0.1,
) -> torch.Tensor:
    """
    Example GRPO Loss Function for RLTrainer
    """
    logprobs: torch.Tensor = compute_logprobs(logits, response)

    # Note: This is also available in losses.grpo_loss via `SimpleGRPOLoss`
    kl = torch.exp(ref_logprobs - logprobs) - (ref_logprobs - logprobs) - 1
    per_token_policy_loss = torch.exp(logprobs - logprobs.detach()) * advantages
    per_token_loss = -(per_token_policy_loss - beta * kl)
    loss = (
        ((per_token_loss * padding_mask).sum(dim=1))
        / (padding_mask.sum(dim=1).clamp(min=1.0))
    ).mean()
    return loss

# %% [markdown]
# ## Define Reward

# %%
@dataclass
class RewardActor(ForgeActor):
    """Reward actor that uses a list of scoring functions."""

    reward_functions: list[Callable]

    @endpoint
    async def evaluate_response(self, prompt: str, response: str, target: str) -> float:
        total_rewards = 0.0
        for reward_fn in self.reward_functions:
            reward = reward_fn(prompt, response, target)
            total_rewards += reward

            # Get a name for the reward function (works for classes, functions, lambdas)
            reward_fn_name = getattr(
                reward_fn, "__name__", reward_fn.__class__.__name__
            )
            # per function reward
            record_metric(
                f"reward/evaluate_response/sum_{reward_fn_name}_reward",
                reward,
                Reduce.SUM,
            )
            record_metric(
                f"reward/evaluate_response/avg_{reward_fn_name}_reward",
                reward,
                Reduce.MEAN,
            )
            record_metric(
                f"reward/evaluate_response/std_{reward_fn_name}_reward",
                reward,
                Reduce.STD,
            )

            # avg total reward
            record_metric(
                "reward/evaluate_response/avg_total_reward",
                reward,
                Reduce.MEAN,
            )

            # count fn calls
            record_metric(
                f"reward/evaluate_response/count_{reward_fn_name}_calls",
                1,
                Reduce.SUM,
            )

        avg_reward = total_rewards / len(self.reward_functions)
        return avg_reward


@dataclass
class ComputeAdvantages(ForgeActor):
    """Compute advantages for GRPO using reward signals."""

    @endpoint
    async def compute(self, group: Group) -> list[float]:
        # TODO: add batch processing
        rewards = torch.tensor([[e.reward for e in group.episodes]])
        mean = rewards.mean(1, keepdim=True)
        std = rewards.std(1, keepdim=True)
        advantages = (rewards - mean) / (std + 1e-4)
        return advantages.squeeze(0).tolist()

# %%
async def drop_weights(version: int):
    print(f"Dropping weights @ version {version}")
    start_time = time.perf_counter()
    prefix = get_param_prefix(version)
    matching_keys = await ts.keys(prefix)
    # TODO: once we have something like `get_meta()` in torchstore, we can just
    # query the type of the object instead of relying on keys.
    dcp_key = get_dcp_whole_state_dict_key(version)
    if dcp_key in matching_keys:
        dcp_handle = await ts.get(dcp_key)
        dcp_handle.drop()
    for key in matching_keys:
        await ts.delete(key)
    elapsed = time.perf_counter() - start_time
    print(f"Dropped weights @ version {version}, took {elapsed:.2f} seconds")

# %% [markdown]
# ## Setup Services

# %%
from omegaconf import OmegaConf
from forge.util.config import resolve_hf_hub_paths

cfg = OmegaConf.load('qwen3_1_7b.yaml')
cfg = resolve_hf_hub_paths(cfg)
OmegaConf.resolve(cfg)

group_size = cfg.group_size # 8
max_req_tokens = cfg.max_req_tokens # 512
max_res_tokens = cfg.max_res_tokens # 512

# metric_logging_cfg = cfg.get("metric_logging", {"console": {"log_per_rank": False}})
# mlogger = await get_or_create_metric_logger()
# await mlogger.init_backends.call_one(metric_logging_cfg)
await ts.initialize(strategy=ts.ControllerStorageVolumes())

dataloader, policy, trainer, replay_buffer, compute_advantages, ref_model, reward_actor = await asyncio.gather(
    DatasetActor.options(**cfg.actors.dataset).as_actor(**cfg.dataset),
    Policy.options(**cfg.services.policy).as_service(**cfg.policy),
    RLTrainer.options(**cfg.actors.trainer).as_actor(
        **cfg.trainer, loss=simple_grpo_loss
    ),
    ReplayBuffer.options(**cfg.actors.replay_buffer).as_actor(
        **cfg.replay_buffer, collate=collate
    ),
    ComputeAdvantages.options(**cfg.actors.compute_advantages).as_actor(),
    ReferenceModel.options(**cfg.services.ref_model).as_service(**cfg.ref_model),
    RewardActor.options(**cfg.services.reward_actor).as_service(
        reward_functions=[MathReward(), ThinkingReward()]
    ),
)

# %% [markdown]
# ## Rollout Loop

# %%
async def continuous_rollouts():
    rollout_count = 0
    pad_id = await dataloader.pad_token.call_one()
    while True:
        t = Tracer("main_perf/continuous_rollouts")
        t.start()
        sample = await dataloader.sample.call_one()
        if sample is None:
            print("Dataloader is empty, exiting continuous rollout")
            return

        t.step("data_loading")

        prompt, target = sample["request"], sample["target"]
        responses = await policy.generate.route(prompt)
        # TODO: this shall be part of the responses metadata instead of a separate call
        version = await policy.get_version.route()

        t.step("policy_generation")

        assert (
            len(responses) > 0
        ), "Sanity check: Responses should NEVER return empty"
        assert (
            version := responses[0].generator_version
        ) is not None, "Response must indicate a version"
        group = Group.new_group(
            group_id=rollout_count,
            group_size=group_size,
            request=prompt,
            policy_version=version,
            pad_id=pad_id,
            request_len=max_req_tokens,
            response_len=max_res_tokens,
            target=target,
        )

        input_ids = torch.ones(
            (group_size, max_req_tokens + max_res_tokens),
            dtype=torch.long,
            device="cuda",
        )
        # Populate episode info and calculate rewards
        for i, (episode, response) in enumerate(zip(group.episodes, responses)):
            episode.request_tokens = response.prompt_ids
            episode.response_tokens = response.token_ids
            episode.response = response.text
            input_ids[i, :max_req_tokens] = episode.request_tensor
            input_ids[i, max_req_tokens:] = episode.response_tensor
            episode.reward = await reward_actor.evaluate_response.route(
                prompt=prompt, response=response.text, target=target
            )

        t.step("reward_evaluation")

        ref_logprobs = await ref_model.forward.route(
            input_ids, max_req_tokens, return_logprobs=True
        )
        t.step("reference_model_calculate_logprobs")

        for i, episode in enumerate(group.episodes):
            episode.ref_logprobs = ref_logprobs[i]
        del ref_logprobs, input_ids
        t.step("compute_logprobs")

        # Calculate advantages and add to replay buffer
        advantages = await compute_advantages.compute.call_one(group)
        for episode, advantage in zip(group.episodes, advantages):
            episode.advantage = advantage
            await replay_buffer.add.call_one(episode)

        # Log metrics
        rollout_count += 1
        record_metric(
            "main/continuous_rollouts/count_rollout_iterations", 1, Reduce.SUM
        )
        t.stop()

# %% [markdown]
# ## Training Loop

# %%
async def continuous_training():
    training_step = 0
    restart_tracer = True  # Flag to control when to restart tracer
    while True:
        # Restart tracer when needed (initial start or after completing a training step)
        # Otherwise, we cannot measure time waiting for buffer
        if restart_tracer:
            t = Tracer("main_perf/continuous_training")
            t.start()
            restart_tracer = False

        batch = await replay_buffer.sample.call_one(
            curr_policy_version=training_step
        )
        if batch is None:
            await asyncio.sleep(0.1)
        else:
            t.step("waiting_for_buffer")

            inputs, targets = batch
            await trainer.train_step.call(inputs, targets)
            training_step += 1
            t.step("train_step")

            await trainer.push_weights.call(training_step)
            t.step("push_weights")

            await policy.update_weights.fanout(training_step)
            update_task = asyncio.create_task(policy.update_weights.fanout(training_step))
            t.step("update_weights")

            if training_step >= 2:
                await drop_weights(training_step - 1)
                t.step("drop_weights")

            t.stop()
            restart_tracer = True

            #Flush metrics every training step to WandB
            # await mlogger.flush.call_one(training_step)

# %% [markdown]
# ## Run

# %%
num_rollout_threads = 1
num_training_threads = 1

rollout_tasks = [
    asyncio.create_task(continuous_rollouts()) for _ in range(num_rollout_threads)
]
training_task = asyncio.create_task(continuous_training())

try:
    await asyncio.gather(*rollout_tasks, training_task)
except KeyboardInterrupt:
    print("Training interrupted by user")
    for rollout_task in rollout_tasks:
        rollout_task.cancel()
    training_task.cancel()

# %% [markdown]
# ## Shutdown

# %%
# await mlogger.shutdown.call_one()
await asyncio.sleep(2)

await asyncio.gather(
    DatasetActor.shutdown(dataloader),
    policy.shutdown(),
    RLTrainer.shutdown(trainer),
    ReplayBuffer.shutdown(replay_buffer),
    ComputeAdvantages.shutdown(compute_advantages),
    ref_model.shutdown(),
    reward_actor.shutdown(),
)
await shutdown()
# Out:
# [-]E1022 05:20:42.144746 34449 hyperactor/src/channel/net.rs:885] error_msg:session unix:@YXhNkLiUffsWW1ZuT0awzwK9.3527921909132156069: failed to receive ack within timeout 30 secs; link is currently broken
# [-]E1022 05:20:42.145625 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@YXhNkLiUffsWW1ZuT0awzwK9,anon_0_1e4WEAMnLrYN,agent[0][16476089041836231337<hyperactor_mesh::resource::GetRankStatus>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:11.961576709+00:00,hyperactor_mesh::comm::multicast::cast_originating_sender=unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0],hyperactor_mesh::comm::multicast::cast_point=hosts=0/1, data:GetRankStatus{"name":{"Suffixed":"[\"comm\",[...28 chars] CRC:257cbf15 5b 22 63 6f 6d 6d 22 2c [...20 bytes]"},"reply":{"phantom":null,"port_id":"[[{\"Dire[...93 chars] CRC:660dea5c 5b 5b 7b 22 44 69 72 65 [...85 bytes]","reducer_opts":null,"reducer_spec":{"builder_params":null,"typehash":4493460774099310317}}}
# [-]E1022 05:20:42.145860 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@YXhNkLiUffsWW1ZuT0awzwK9,anon_0_1e4WEAMnLrYN,comm_14GATFobDCHq[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.123330023+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[104803[...125 chars] CRC:424d5e55 5b 5b 31 30 34 38 30 33 [...117 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...287 chars] CRC:67a92c98 5b 30 2c 30 2c 30 2c 30 [...279 bytes]","is_illegal":false,"parts":[]}},"typehash":1330557499926649425}},"dest_port":{"actor_name":"agent","port":10639140449372694939},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.145905 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@YXhNkLiUffsWW1ZuT0awzwK9,anon_0_1e4WEAMnLrYN,comm_14GATFobDCHq[0][9438540675267141827<hyperactor_mesh::comm::CommActorMode>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.071235402+00:00, data:CommActorMode{"Mesh":"[0,{\"0\":[...105 chars] CRC:829395f8 5b 30 2c 7b 22 30 22 3a [...97 bytes]"}
# [-]E1022 05:20:42.145972 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@YXhNkLiUffsWW1ZuT0awzwK9,anon_0_1e4WEAMnLrYN,comm_14GATFobDCHq[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.071580958+00:00,hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[104803[...125 chars] CRC:424d5e55 5b 5b 31 30 34 38 30 33 [...117 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...626 chars] CRC:b56731b 5b 30 2c 30 2c 30 2c 30 [...618 bytes]","is_illegal":false,"parts":[]}},"typehash":1330557499926649425}},"dest_port":{"actor_name":"agent","port":10639140449372694939},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.146026 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@YXhNkLiUffsWW1ZuT0awzwK9,anon_0_1e4WEAMnLrYN,comm_14GATFobDCHq[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.071613182+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[119644[...444 chars] CRC:cc66b409 5b 5b 31 31 39 36 34 34 [...436 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...426 chars] CRC:8d57e55e 5b 30 2c 30 2c 30 2c 30 [...418 bytes]","is_illegal":false,"parts":[]}},"typehash":7252717004981455529}},"dest_port":{"actor_name":"agent","port":9548687619301914726},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.146073 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@YXhNkLiUffsWW1ZuT0awzwK9,anon_0_1e4WEAMnLrYN,comm_14GATFobDCHq[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.177206720+00:00,hyperactor_mesh::actor_mesh::cast_actor_mesh_id=log_forwarder_1rgFeG41VVQc, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Suffixed":"[\"log_fo[...38 chars] CRC:3b1dc3bb 5b 22 6c 6f 67 5f 66 6f [...30 bytes]"}},"data":{"bindings":[],"message":{"encoded":{"Multipart":{"body":"[1,0,0,0[...11 chars] CRC:5597ea9f 5b 31 2c 30 2c 30 2c 30 [...3 bytes]","is_illegal":false,"parts":[]}},"typehash":12098283485503622895}},"dest_port":{"actor_name":"log_forw[...26 chars] CRC:9c5f00cc 6c 6f 67 5f 66 6f 72 77 [...18 bytes]","port":18039862042805291298},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.146125 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@YXhNkLiUffsWW1ZuT0awzwK9,anon_0_1e4WEAMnLrYN,comm_14GATFobDCHq[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.123354214+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[119644[...444 chars] CRC:edf46a61 5b 5b 31 31 39 36 34 34 [...436 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...398 chars] CRC:4c7020a5 5b 30 2c 30 2c 30 2c 30 [...390 bytes]","is_illegal":false,"parts":[]}},"typehash":7252717004981455529}},"dest_port":{"actor_name":"agent","port":9548687619301914726},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.146173 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@YXhNkLiUffsWW1ZuT0awzwK9,anon_0_1e4WEAMnLrYN,comm_14GATFobDCHq[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.177228191+00:00,hyperactor_mesh::actor_mesh::cast_actor_mesh_id=logger_1a9TggktcZyb, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Suffixed":"[\"logger[...30 chars] CRC:ce10927 5b 22 6c 6f 67 67 65 72 [...22 bytes]"}},"data":{"bindings":[],"message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...12 chars] CRC:b564c5bf 5b 30 2c 30 2c 30 2c 30 [...4 bytes]","is_illegal":false,"parts":[]}},"typehash":10911722563623013595}},"dest_port":{"actor_name":"logger_1[...19 chars] CRC:c95dc67b 6c 6f 67 67 65 72 5f 31 [...11 bytes]","port":10648924583654510167},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.244292 34449 hyperactor/src/channel/net.rs:872] error_msg:session unix:@5XLAQAQYcAjf2axX8mo3oAEW.16147195979676164651: failed to deliver message within timeout
# [-]E1022 05:20:42.244428 34449 hyperactor/src/mailbox.rs:782] message not delivered, broken link: message returned to undeliverable port, name:undelivered_message_abandoned, actor_name:drop, actor_id:unix:@5eF0AzA2h1yWQl8ht9bJ4Dwf,hostmesh-drop,drop[0], dest:unix:@5XLAQAQYcAjf2axX8mo3oAEW,service,agent[0][15110393541797216600<hyperactor_mesh::v1::host_mesh::mesh_agent::ShutdownHost>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.155698704+00:00, data:ShutdownHost{"ack":{"phantom":null,"port_id":"[[{\"Dire[...83 chars] CRC:f2b46034 5b 5b 7b 22 44 69 72 65 [...75 bytes]","reducer_opts":null,"reducer_spec":null},"max_in_flight":16,"timeout":{"nanos":0,"secs":10}}
# [-]E1022 05:20:42.264513 34449 hyperactor/src/channel/net.rs:872] error_msg:session unix:@M8FwseeGor5KAwl6TQMbKFAm.18051644620848501683: failed to deliver message within timeout
# [-]E1022 05:20:42.264570 34449 hyperactor/src/mailbox.rs:782] message not delivered, broken link: message returned to undeliverable port, name:undelivered_message_abandoned, actor_name:drop, actor_id:unix:@xL86G1LGx4fV2ET2D3HHEe8W,hostmesh-drop,drop[0], dest:unix:@M8FwseeGor5KAwl6TQMbKFAm,service,agent[0][15110393541797216600<hyperactor_mesh::v1::host_mesh::mesh_agent::ShutdownHost>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.152129195+00:00, data:ShutdownHost{"ack":{"phantom":null,"port_id":"[[{\"Dire[...83 chars] CRC:3a703eb2 5b 5b 7b 22 44 69 72 65 [...75 bytes]","reducer_opts":null,"reducer_spec":null},"max_in_flight":16,"timeout":{"nanos":0,"secs":10}}
# [-]E1022 05:20:42.300775 34449 hyperactor/src/channel/net.rs:872] error_msg:session unix:@Hm5w2KLNzFdgAJSsUJNUZyFD.4248410910419323936: failed to deliver message within timeout
# [-]E1022 05:20:42.300850 34449 hyperactor/src/mailbox.rs:782] message not delivered, broken link: message returned to undeliverable port, name:undelivered_message_abandoned, actor_name:drop, actor_id:unix:@wvq1CprclhNXBS0r0SvdPT1Z,hostmesh-drop,drop[0], dest:unix:@Hm5w2KLNzFdgAJSsUJNUZyFD,service,agent[0][15110393541797216600<hyperactor_mesh::v1::host_mesh::mesh_agent::ShutdownHost>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.173783812+00:00, data:ShutdownHost{"ack":{"phantom":null,"port_id":"[[{\"Dire[...83 chars] CRC:d0111c6c 5b 5b 7b 22 44 69 72 65 [...75 bytes]","reducer_opts":null,"reducer_spec":null},"max_in_flight":16,"timeout":{"nanos":0,"secs":10}}
# [-]E1022 05:20:42.463142 34449 hyperactor/src/channel/net.rs:872] error_msg:session unix:@T5R7uI68QdwObpLARXNzXmEJ.10763839054571299090: failed to deliver message within timeout
# [-]E1022 05:20:42.463243 34449 hyperactor/src/mailbox.rs:782] message not delivered, broken link: message returned to undeliverable port, name:undelivered_message_abandoned, actor_name:drop, actor_id:unix:@Uc0VzmMx6VsmDsjzUlRctg9M,hostmesh-drop,drop[0], dest:unix:@T5R7uI68QdwObpLARXNzXmEJ,service,agent[0][15110393541797216600<hyperactor_mesh::v1::host_mesh::mesh_agent::ShutdownHost>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.212341345+00:00, data:ShutdownHost{"ack":{"phantom":null,"port_id":"[[{\"Dire[...83 chars] CRC:36e33cf0 5b 5b 7b 22 44 69 72 65 [...75 bytes]","reducer_opts":null,"reducer_spec":null},"max_in_flight":16,"timeout":{"nanos":0,"secs":10}}
# [-]E1022 05:20:42.604563 34449 hyperactor/src/channel/net.rs:885] error_msg:session unix:@Hm5w2KLNzFdgAJSsUJNUZyFD.611139676789305961: failed to receive ack within timeout 30 secs; link is currently broken
# [-]E1022 05:20:42.604779 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@Hm5w2KLNzFdgAJSsUJNUZyFD,anon_0_1CrgaTrC5Fin,comm_16ijZZvNpRwv[0][9438540675267141827<hyperactor_mesh::comm::CommActorMode>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.069092043+00:00, data:CommActorMode{"Mesh":"[0,{\"0\":[...105 chars] CRC:5488205a 5b 30 2c 7b 22 30 22 3a [...97 bytes]"}
# [-]E1022 05:20:42.604881 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@Hm5w2KLNzFdgAJSsUJNUZyFD,anon_0_1CrgaTrC5Fin,comm_16ijZZvNpRwv[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.069386459+00:00,hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[104803[...125 chars] CRC:424d5e55 5b 5b 31 30 34 38 30 33 [...117 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...620 chars] CRC:1e650468 5b 30 2c 30 2c 30 2c 30 [...612 bytes]","is_illegal":false,"parts":[]}},"typehash":1330557499926649425}},"dest_port":{"actor_name":"agent","port":10639140449372694939},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.604950 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@Hm5w2KLNzFdgAJSsUJNUZyFD,anon_0_1CrgaTrC5Fin,comm_16ijZZvNpRwv[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.069407698+00:00,hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[119644[...444 chars] CRC:1ab6767a 5b 5b 31 31 39 36 34 34 [...436 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...424 chars] CRC:49d4ddee 5b 30 2c 30 2c 30 2c 30 [...416 bytes]","is_illegal":false,"parts":[]}},"typehash":7252717004981455529}},"dest_port":{"actor_name":"agent","port":9548687619301914726},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.605000 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@Hm5w2KLNzFdgAJSsUJNUZyFD,anon_0_1CrgaTrC5Fin,comm_16ijZZvNpRwv[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.121907650+00:00,hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[104803[...125 chars] CRC:424d5e55 5b 5b 31 30 34 38 30 33 [...117 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...288 chars] CRC:5dc31ef1 5b 30 2c 30 2c 30 2c 30 [...280 bytes]","is_illegal":false,"parts":[]}},"typehash":1330557499926649425}},"dest_port":{"actor_name":"agent","port":10639140449372694939},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.605057 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@Hm5w2KLNzFdgAJSsUJNUZyFD,anon_0_1CrgaTrC5Fin,comm_16ijZZvNpRwv[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.121930301+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[119644[...444 chars] CRC:761058f9 5b 5b 31 31 39 36 34 34 [...436 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...399 chars] CRC:2ed2556f 5b 30 2c 30 2c 30 2c 30 [...391 bytes]","is_illegal":false,"parts":[]}},"typehash":7252717004981455529}},"dest_port":{"actor_name":"agent","port":9548687619301914726},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.605108 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@Hm5w2KLNzFdgAJSsUJNUZyFD,anon_0_1CrgaTrC5Fin,comm_16ijZZvNpRwv[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.173371511+00:00,hyperactor_mesh::actor_mesh::cast_actor_mesh_id=log_forwarder_1uysDSwkvpbg, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Suffixed":"[\"log_fo[...38 chars] CRC:ae94e2a 5b 22 6c 6f 67 5f 66 6f [...30 bytes]"}},"data":{"bindings":[],"message":{"encoded":{"Multipart":{"body":"[1,0,0,0[...11 chars] CRC:5597ea9f 5b 31 2c 30 2c 30 2c 30 [...3 bytes]","is_illegal":false,"parts":[]}},"typehash":12098283485503622895}},"dest_port":{"actor_name":"log_forw[...26 chars] CRC:da736071 6c 6f 67 5f 66 6f 72 77 [...18 bytes]","port":18039862042805291298},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.605155 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@Hm5w2KLNzFdgAJSsUJNUZyFD,anon_0_1CrgaTrC5Fin,comm_16ijZZvNpRwv[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=logger_1CJrmjZiMKtm,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.173390079+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Suffixed":"[\"logger[...31 chars] CRC:97bb1307 5b 22 6c 6f 67 67 65 72 [...23 bytes]"}},"data":{"bindings":[],"message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...12 chars] CRC:b564c5bf 5b 30 2c 30 2c 30 2c 30 [...4 bytes]","is_illegal":false,"parts":[]}},"typehash":10911722563623013595}},"dest_port":{"actor_name":"logger_1[...19 chars] CRC:2461bd7a 6c 6f 67 67 65 72 5f 31 [...11 bytes]","port":10648924583654510167},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.605209 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@Hm5w2KLNzFdgAJSsUJNUZyFD,anon_0_1CrgaTrC5Fin,agent[0][16476089041836231337<hyperactor_mesh::resource::GetRankStatus>], headers:hyperactor_mesh::comm::multicast::cast_originating_sender=unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0],hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:11.961559637+00:00,hyperactor_mesh::comm::multicast::cast_point=hosts=0/1, data:GetRankStatus{"name":{"Suffixed":"[\"comm\",[...28 chars] CRC:ab785793 5b 22 63 6f 6d 6d 22 2c [...20 bytes]"},"reply":{"phantom":null,"port_id":"[[{\"Dire[...93 chars] CRC:543b88de 5b 5b 7b 22 44 69 72 65 [...85 bytes]","reducer_opts":null,"reducer_spec":{"builder_params":null,"typehash":4493460774099310317}}}
# [-]E1022 05:20:42.659125 34449 hyperactor/src/channel/net.rs:885] error_msg:session unix:@qNRSoQFkEGh9arVvKzjVlrf6.7467493038379146136: failed to receive ack within timeout 30 secs; link is currently broken
# [-]E1022 05:20:42.659325 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@qNRSoQFkEGh9arVvKzjVlrf6,anon_0_1HbyrkjfRhTh,comm_1AXKLjsEdVrf[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.147455393+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[104803[...125 chars] CRC:424d5e55 5b 5b 31 30 34 38 30 33 [...117 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...619 chars] CRC:41bacd0d 5b 30 2c 30 2c 30 2c 30 [...611 bytes]","is_illegal":false,"parts":[]}},"typehash":1330557499926649425}},"dest_port":{"actor_name":"agent","port":10639140449372694939},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.659391 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@qNRSoQFkEGh9arVvKzjVlrf6,anon_0_1HbyrkjfRhTh,comm_1AXKLjsEdVrf[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.147478437+00:00,hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[119644[...444 chars] CRC:3b24a812 5b 5b 31 31 39 36 34 34 [...436 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...423 chars] CRC:927e9ce9 5b 30 2c 30 2c 30 2c 30 [...415 bytes]","is_illegal":false,"parts":[]}},"typehash":7252717004981455529}},"dest_port":{"actor_name":"agent","port":9548687619301914726},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.659442 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@qNRSoQFkEGh9arVvKzjVlrf6,anon_0_1HbyrkjfRhTh,comm_1AXKLjsEdVrf[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.199844396+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[104803[...125 chars] CRC:424d5e55 5b 5b 31 30 34 38 30 33 [...117 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...286 chars] CRC:25abac62 5b 30 2c 30 2c 30 2c 30 [...278 bytes]","is_illegal":false,"parts":[]}},"typehash":1330557499926649425}},"dest_port":{"actor_name":"agent","port":10639140449372694939},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.659494 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@qNRSoQFkEGh9arVvKzjVlrf6,anon_0_1HbyrkjfRhTh,comm_1AXKLjsEdVrf[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.199870608+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[119644[...444 chars] CRC:27c9e06f 5b 5b 31 31 39 36 34 34 [...436 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...397 chars] CRC:a1348a27 5b 30 2c 30 2c 30 2c 30 [...389 bytes]","is_illegal":false,"parts":[]}},"typehash":7252717004981455529}},"dest_port":{"actor_name":"agent","port":9548687619301914726},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.659543 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@qNRSoQFkEGh9arVvKzjVlrf6,anon_0_1HbyrkjfRhTh,comm_1AXKLjsEdVrf[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=log_forwarder_1bTzwKExpmFu,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.252341138+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Suffixed":"[\"log_fo[...37 chars] CRC:cfd06969 5b 22 6c 6f 67 5f 66 6f [...29 bytes]"}},"data":{"bindings":[],"message":{"encoded":{"Multipart":{"body":"[1,0,0,0[...11 chars] CRC:5597ea9f 5b 31 2c 30 2c 30 2c 30 [...3 bytes]","is_illegal":false,"parts":[]}},"typehash":12098283485503622895}},"dest_port":{"actor_name":"log_forw[...26 chars] CRC:49fbbdd0 6c 6f 67 5f 66 6f 72 77 [...18 bytes]","port":18039862042805291298},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.659589 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@qNRSoQFkEGh9arVvKzjVlrf6,anon_0_1HbyrkjfRhTh,comm_1AXKLjsEdVrf[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=logger_1oNa1PXaXLQa,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.252364162+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Suffixed":"[\"logger[...30 chars] CRC:c1b19000 5b 22 6c 6f 67 67 65 72 [...22 bytes]"}},"data":{"bindings":[],"message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...12 chars] CRC:b564c5bf 5b 30 2c 30 2c 30 2c 30 [...4 bytes]","is_illegal":false,"parts":[]}},"typehash":10911722563623013595}},"dest_port":{"actor_name":"logger_1[...19 chars] CRC:c4aea51f 6c 6f 67 67 65 72 5f 31 [...11 bytes]","port":10648924583654510167},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.659634 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@qNRSoQFkEGh9arVvKzjVlrf6,anon_0_1HbyrkjfRhTh,agent[0][16476089041836231337<hyperactor_mesh::resource::GetRankStatus>], headers:hyperactor_mesh::comm::multicast::cast_point=hosts=0/1,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.038336265+00:00,hyperactor_mesh::comm::multicast::cast_originating_sender=unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], data:GetRankStatus{"name":{"Suffixed":"[\"comm\",[...29 chars] CRC:2ea1fd75 5b 22 63 6f 6d 6d 22 2c [...21 bytes]"},"reply":{"phantom":null,"port_id":"[[{\"Dire[...93 chars] CRC:4ce2d3a8 5b 5b 7b 22 44 69 72 65 [...85 bytes]","reducer_opts":null,"reducer_spec":{"builder_params":null,"typehash":4493460774099310317}}}
# [-]E1022 05:20:42.659680 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@qNRSoQFkEGh9arVvKzjVlrf6,anon_0_1HbyrkjfRhTh,comm_1AXKLjsEdVrf[0][9438540675267141827<hyperactor_mesh::comm::CommActorMode>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.147141944+00:00, data:CommActorMode{"Mesh":"[0,{\"0\":[...105 chars] CRC:b24f96e5 5b 30 2c 7b 22 30 22 3a [...97 bytes]"}
# [-]E1022 05:20:42.698338 34449 hyperactor/src/channel/net.rs:872] error_msg:session unix:@YXhNkLiUffsWW1ZuT0awzwK9.15183646532156613629: failed to deliver message within timeout
# [-]E1022 05:20:42.698420 34449 hyperactor/src/mailbox.rs:782] message not delivered, broken link: message returned to undeliverable port, name:undelivered_message_abandoned, actor_name:drop, actor_id:unix:@6fnX72nkc5TK0KNzyUytds6g,hostmesh-drop,drop[0], dest:unix:@YXhNkLiUffsWW1ZuT0awzwK9,service,agent[0][15110393541797216600<hyperactor_mesh::v1::host_mesh::mesh_agent::ShutdownHost>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.177603652+00:00, data:ShutdownHost{"ack":{"phantom":null,"port_id":"[[{\"Dire[...83 chars] CRC:dd970284 5b 5b 7b 22 44 69 72 65 [...75 bytes]","reducer_opts":null,"reducer_spec":null},"max_in_flight":16,"timeout":{"nanos":0,"secs":10}}
# [-]E1022 05:20:42.817662 34449 hyperactor/src/channel/net.rs:885] error_msg:session unix:@5XLAQAQYcAjf2axX8mo3oAEW.2120597817167434532: failed to receive ack within timeout 30 secs; link is currently broken
# [-]E1022 05:20:42.817820 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@5XLAQAQYcAjf2axX8mo3oAEW,anon_0_1jriYD8rZMds,agent[0][16476089041836231337<hyperactor_mesh::resource::GetRankStatus>], headers:hyperactor_mesh::comm::multicast::cast_point=hosts=0/1,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:11.946685295+00:00,hyperactor_mesh::comm::multicast::cast_originating_sender=unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], data:GetRankStatus{"name":{"Suffixed":"[\"comm\",[...29 chars] CRC:3a23153f 5b 22 63 6f 6d 6d 22 2c [...21 bytes]"},"reply":{"phantom":null,"port_id":"[[{\"Dire[...93 chars] CRC:1b7a1e19 5b 5b 7b 22 44 69 72 65 [...85 bytes]","reducer_opts":null,"reducer_spec":{"builder_params":null,"typehash":4493460774099310317}}}
# [-]E1022 05:20:42.817861 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@5XLAQAQYcAjf2axX8mo3oAEW,anon_0_1jriYD8rZMds,comm_1FgCZfwZRE9m[0][9438540675267141827<hyperactor_mesh::comm::CommActorMode>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.049298001+00:00, data:CommActorMode{"Mesh":"[0,{\"0\":[...105 chars] CRC:cf4400fe 5b 30 2c 7b 22 30 22 3a [...97 bytes]"}
# [-]E1022 05:20:42.817953 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@5XLAQAQYcAjf2axX8mo3oAEW,anon_0_1jriYD8rZMds,comm_1FgCZfwZRE9m[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.102431223+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[119644[...444 chars] CRC:28c0ca6b 5b 5b 31 31 39 36 34 34 [...436 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...397 chars] CRC:2de73417 5b 30 2c 30 2c 30 2c 30 [...389 bytes]","is_illegal":false,"parts":[]}},"typehash":7252717004981455529}},"dest_port":{"actor_name":"agent","port":9548687619301914726},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.818004 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@5XLAQAQYcAjf2axX8mo3oAEW,anon_0_1jriYD8rZMds,comm_1FgCZfwZRE9m[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.102413665+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[104803[...125 chars] CRC:424d5e55 5b 5b 31 30 34 38 30 33 [...117 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...286 chars] CRC:c5fc26c4 5b 30 2c 30 2c 30 2c 30 [...278 bytes]","is_illegal":false,"parts":[]}},"typehash":1330557499926649425}},"dest_port":{"actor_name":"agent","port":10639140449372694939},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.818076 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@5XLAQAQYcAjf2axX8mo3oAEW,anon_0_1jriYD8rZMds,comm_1FgCZfwZRE9m[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.049548166+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[104803[...125 chars] CRC:424d5e55 5b 5b 31 30 34 38 30 33 [...117 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...625 chars] CRC:fc35b984 5b 30 2c 30 2c 30 2c 30 [...617 bytes]","is_illegal":false,"parts":[]}},"typehash":1330557499926649425}},"dest_port":{"actor_name":"agent","port":10639140449372694939},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.818125 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@5XLAQAQYcAjf2axX8mo3oAEW,anon_0_1jriYD8rZMds,comm_1FgCZfwZRE9m[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.049578227+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[119644[...444 chars] CRC:3d33c47a 5b 5b 31 31 39 36 34 34 [...436 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...428 chars] CRC:ed2a17d3 5b 30 2c 30 2c 30 2c 30 [...420 bytes]","is_illegal":false,"parts":[]}},"typehash":7252717004981455529}},"dest_port":{"actor_name":"agent","port":9548687619301914726},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.818176 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@5XLAQAQYcAjf2axX8mo3oAEW,anon_0_1jriYD8rZMds,comm_1FgCZfwZRE9m[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.155270726+00:00,hyperactor_mesh::actor_mesh::cast_actor_mesh_id=log_forwarder_1FEJfLd7BxiZ, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Suffixed":"[\"log_fo[...38 chars] CRC:85c6f8 5b 22 6c 6f 67 5f 66 6f [...30 bytes]"}},"data":{"bindings":[],"message":{"encoded":{"Multipart":{"body":"[1,0,0,0[...11 chars] CRC:5597ea9f 5b 31 2c 30 2c 30 2c 30 [...3 bytes]","is_illegal":false,"parts":[]}},"typehash":12098283485503622895}},"dest_port":{"actor_name":"log_forw[...26 chars] CRC:3042934 6c 6f 67 5f 66 6f 72 77 [...18 bytes]","port":18039862042805291298},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.818226 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@5XLAQAQYcAjf2axX8mo3oAEW,anon_0_1jriYD8rZMds,comm_1FgCZfwZRE9m[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=logger_1gKNq3jtBUMY,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.155289048+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Suffixed":"[\"logger[...30 chars] CRC:4e0b5f4d 5b 22 6c 6f 67 67 65 72 [...22 bytes]"}},"data":{"bindings":[],"message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...12 chars] CRC:b564c5bf 5b 30 2c 30 2c 30 2c 30 [...4 bytes]","is_illegal":false,"parts":[]}},"typehash":10911722563623013595}},"dest_port":{"actor_name":"logger_1[...19 chars] CRC:555b226a 6c 6f 67 67 65 72 5f 31 [...11 bytes]","port":10648924583654510167},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.877129 34449 hyperactor/src/channel/net.rs:885] error_msg:session unix:@T5R7uI68QdwObpLARXNzXmEJ.12330821112224102444: failed to receive ack within timeout 30 secs; link is currently broken
# [-]E1022 05:20:42.877296 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@T5R7uI68QdwObpLARXNzXmEJ,anon_0_1xsQCFz1nf3R,agent[0][16476089041836231337<hyperactor_mesh::resource::GetRankStatus>], headers:hyperactor_mesh::comm::multicast::cast_originating_sender=unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0],hyperactor_mesh::comm::multicast::cast_point=hosts=0/1,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:11.996575811+00:00, data:GetRankStatus{"name":{"Suffixed":"[\"comm\",[...28 chars] CRC:f0e6bcbb 5b 22 63 6f 6d 6d 22 2c [...20 bytes]"},"reply":{"phantom":null,"port_id":"[[{\"Dire[...93 chars] CRC:319527ed 5b 5b 7b 22 44 69 72 65 [...85 bytes]","reducer_opts":null,"reducer_spec":{"builder_params":null,"typehash":4493460774099310317}}}
# [-]E1022 05:20:42.877336 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@T5R7uI68QdwObpLARXNzXmEJ,anon_0_1xsQCFz1nf3R,comm_1o6u4DguBroo[0][9438540675267141827<hyperactor_mesh::comm::CommActorMode>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.107633265+00:00, data:CommActorMode{"Mesh":"[0,{\"0\":[...105 chars] CRC:9d6846d4 5b 30 2c 7b 22 30 22 3a [...97 bytes]"}
# [-]E1022 05:20:42.877402 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@T5R7uI68QdwObpLARXNzXmEJ,anon_0_1xsQCFz1nf3R,comm_1o6u4DguBroo[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.159394072+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[104803[...125 chars] CRC:424d5e55 5b 5b 31 30 34 38 30 33 [...117 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...288 chars] CRC:58762e5b 5b 30 2c 30 2c 30 2c 30 [...280 bytes]","is_illegal":false,"parts":[]}},"typehash":1330557499926649425}},"dest_port":{"actor_name":"agent","port":10639140449372694939},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.877472 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@T5R7uI68QdwObpLARXNzXmEJ,anon_0_1xsQCFz1nf3R,comm_1o6u4DguBroo[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.107982191+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[104803[...125 chars] CRC:424d5e55 5b 5b 31 30 34 38 30 33 [...117 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...621 chars] CRC:81091aa1 5b 30 2c 30 2c 30 2c 30 [...613 bytes]","is_illegal":false,"parts":[]}},"typehash":1330557499926649425}},"dest_port":{"actor_name":"agent","port":10639140449372694939},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.877529 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@T5R7uI68QdwObpLARXNzXmEJ,anon_0_1xsQCFz1nf3R,comm_1o6u4DguBroo[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.108013697+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[119644[...444 chars] CRC:fe100818 5b 5b 31 31 39 36 34 34 [...436 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...424 chars] CRC:3f09e8e0 5b 30 2c 30 2c 30 2c 30 [...416 bytes]","is_illegal":false,"parts":[]}},"typehash":7252717004981455529}},"dest_port":{"actor_name":"agent","port":9548687619301914726},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.877582 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@T5R7uI68QdwObpLARXNzXmEJ,anon_0_1xsQCFz1nf3R,comm_1o6u4DguBroo[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.211907224+00:00,hyperactor_mesh::actor_mesh::cast_actor_mesh_id=log_forwarder_1mKX68qW1wSi, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Suffixed":"[\"log_fo[...37 chars] CRC:fd0684ca 5b 22 6c 6f 67 5f 66 6f [...29 bytes]"}},"data":{"bindings":[],"message":{"encoded":{"Multipart":{"body":"[1,0,0,0[...11 chars] CRC:5597ea9f 5b 31 2c 30 2c 30 2c 30 [...3 bytes]","is_illegal":false,"parts":[]}},"typehash":12098283485503622895}},"dest_port":{"actor_name":"log_forw[...26 chars] CRC:55c16f58 6c 6f 67 5f 66 6f 72 77 [...18 bytes]","port":18039862042805291298},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# ...
# [-]E1022 05:20:42.883847 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@M8FwseeGor5KAwl6TQMbKFAm,anon_0_1s95NpHdbThx,comm_1h67NJeEYTjS[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.098693+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[119644[...444 chars] CRC:4466e4e8 5b 5b 31 31 39 36 34 34 [...436 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...394 chars] CRC:eb75f167 5b 30 2c 30 2c 30 2c 30 [...386 bytes]","is_illegal":false,"parts":[]}},"typehash":7252717004981455529}},"dest_port":{"actor_name":"agent","port":9548687619301914726},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.883897 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@M8FwseeGor5KAwl6TQMbKFAm,anon_0_1s95NpHdbThx,agent[0][16476089041836231337<hyperactor_mesh::resource::GetRankStatus>], headers:hyperactor_mesh::comm::multicast::cast_originating_sender=unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0],hyperactor_mesh::comm::multicast::cast_point=hosts=0/1,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:11.940007721+00:00, data:GetRankStatus{"name":{"Suffixed":"[\"comm\",[...28 chars] CRC:51c7f5d4 5b 22 63 6f 6d 6d 22 2c [...20 bytes]"},"reply":{"phantom":null,"port_id":"[[{\"Dire[...93 chars] CRC:fac8798b 5b 5b 7b 22 44 69 72 65 [...85 bytes]","reducer_opts":null,"reducer_spec":{"builder_params":null,"typehash":4493460774099310317}}}
# [-]E1022 05:20:42.883960 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@M8FwseeGor5KAwl6TQMbKFAm,anon_0_1s95NpHdbThx,comm_1h67NJeEYTjS[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=log_forwarder_1CQ24CLkcjtJ,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.150693613+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Suffixed":"[\"log_fo[...38 chars] CRC:fff01222 5b 22 6c 6f 67 5f 66 6f [...30 bytes]"}},"data":{"bindings":[],"message":{"encoded":{"Multipart":{"body":"[1,0,0,0[...11 chars] CRC:5597ea9f 5b 31 2c 30 2c 30 2c 30 [...3 bytes]","is_illegal":false,"parts":[]}},"typehash":12098283485503622895}},"dest_port":{"actor_name":"log_forw[...26 chars] CRC:5cd27d7 6c 6f 67 5f 66 6f 72 77 [...18 bytes]","port":18039862042805291298},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.884008 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@M8FwseeGor5KAwl6TQMbKFAm,anon_0_1s95NpHdbThx,comm_1h67NJeEYTjS[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.150707385+00:00,hyperactor_mesh::actor_mesh::cast_actor_mesh_id=logger_11Jf9zVtzsgx, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Suffixed":"[\"logger[...29 chars] CRC:71547b67 5b 22 6c 6f 67 67 65 72 [...21 bytes]"}},"data":{"bindings":[],"message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...12 chars] CRC:b564c5bf 5b 30 2c 30 2c 30 2c 30 [...4 bytes]","is_illegal":false,"parts":[]}},"typehash":10911722563623013595}},"dest_port":{"actor_name":"logger_1[...19 chars] CRC:61b566c6 6c 6f 67 67 65 72 5f 31 [...11 bytes]","port":10648924583654510167},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:42.957776 34449 hyperactor/src/channel/net.rs:872] error_msg:session unix:@e11FpMbH7Nv2KO0TnuzmvScm.10742926722564066167: failed to deliver message within timeout
# [-]E1022 05:20:42.957850 34449 hyperactor/src/mailbox.rs:782] message not delivered, broken link: message returned to undeliverable port, name:undelivered_message_abandoned, actor_name:drop, actor_id:unix:@ASwZQZ2t1Zi2nnbmTEsQmoLR,hostmesh-drop,drop[0], dest:unix:@e11FpMbH7Nv2KO0TnuzmvScm,service,agent[0][15110393541797216600<hyperactor_mesh::v1::host_mesh::mesh_agent::ShutdownHost>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.473447193+00:00, data:ShutdownHost{"ack":{"phantom":null,"port_id":"[[{\"Dire[...83 chars] CRC:ea2e5811 5b 5b 7b 22 44 69 72 65 [...75 bytes]","reducer_opts":null,"reducer_spec":null},"max_in_flight":16,"timeout":{"nanos":0,"secs":10}}
# [-]E1022 05:20:43.046152 34449 hyperactor/src/channel/net.rs:872] error_msg:session unix:@qNRSoQFkEGh9arVvKzjVlrf6.192881353479429074: failed to deliver message within timeout
# [-]E1022 05:20:43.046238 34449 hyperactor/src/mailbox.rs:782] message not delivered, broken link: message returned to undeliverable port, name:undelivered_message_abandoned, actor_name:drop, actor_id:unix:@k6TOuaI2bA3Hk84EcLBCn19F,hostmesh-drop,drop[0], dest:unix:@qNRSoQFkEGh9arVvKzjVlrf6,service,agent[0][15110393541797216600<hyperactor_mesh::v1::host_mesh::mesh_agent::ShutdownHost>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.252791621+00:00, data:ShutdownHost{"ack":{"phantom":null,"port_id":"[[{\"Dire[...83 chars] CRC:38c53bc7 5b 5b 7b 22 44 69 72 65 [...75 bytes]","reducer_opts":null,"reducer_spec":null},"max_in_flight":16,"timeout":{"nanos":0,"secs":10}}
# [-]E1022 05:20:43.205502 34449 hyperactor/src/channel/net.rs:885] error_msg:session unix:@e11FpMbH7Nv2KO0TnuzmvScm.1244837023557815421: failed to receive ack within timeout 30 secs; link is currently broken
# [-]E1022 05:20:43.205696 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@e11FpMbH7Nv2KO0TnuzmvScm,anon_0_1sZcWdWgQgSB,comm_11zyPNv7fD2q[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.368009185+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[104803[...125 chars] CRC:424d5e55 5b 5b 31 30 34 38 30 33 [...117 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...620 chars] CRC:e592c0 5b 30 2c 30 2c 30 2c 30 [...612 bytes]","is_illegal":false,"parts":[]}},"typehash":1330557499926649425}},"dest_port":{"actor_name":"agent","port":10639140449372694939},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:43.205787 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@e11FpMbH7Nv2KO0TnuzmvScm,anon_0_1sZcWdWgQgSB,comm_11zyPNv7fD2q[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.368043695+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[119644[...444 chars] CRC:c2e8a10 5b 5b 31 31 39 36 34 34 [...436 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...425 chars] CRC:9115b1d1 5b 30 2c 30 2c 30 2c 30 [...417 bytes]","is_illegal":false,"parts":[]}},"typehash":7252717004981455529}},"dest_port":{"actor_name":"agent","port":9548687619301914726},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:43.205838 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@e11FpMbH7Nv2KO0TnuzmvScm,anon_0_1sZcWdWgQgSB,comm_11zyPNv7fD2q[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.420598640+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[104803[...125 chars] CRC:424d5e55 5b 5b 31 30 34 38 30 33 [...117 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...287 chars] CRC:8f94bce1 5b 30 2c 30 2c 30 2c 30 [...279 bytes]","is_illegal":false,"parts":[]}},"typehash":1330557499926649425}},"dest_port":{"actor_name":"agent","port":10639140449372694939},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:43.205896 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@e11FpMbH7Nv2KO0TnuzmvScm,anon_0_1sZcWdWgQgSB,comm_11zyPNv7fD2q[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=agent,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.420627239+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Reserved":"agent"}},"data":{"bindings":"[[119644[...444 chars] CRC:9088c42d 5b 5b 31 31 39 36 34 34 [...436 bytes]","message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...398 chars] CRC:a7dff3f8 5b 30 2c 30 2c 30 2c 30 [...390 bytes]","is_illegal":false,"parts":[]}},"typehash":7252717004981455529}},"dest_port":{"actor_name":"agent","port":9548687619301914726},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:43.205961 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@e11FpMbH7Nv2KO0TnuzmvScm,anon_0_1sZcWdWgQgSB,comm_11zyPNv7fD2q[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.472937029+00:00,hyperactor_mesh::actor_mesh::cast_actor_mesh_id=log_forwarder_1sJsFGMwCep5, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Suffixed":"[\"log_fo[...38 chars] CRC:87625050 5b 22 6c 6f 67 5f 66 6f [...30 bytes]"}},"data":{"bindings":[],"message":{"encoded":{"Multipart":{"body":"[1,0,0,0[...11 chars] CRC:5597ea9f 5b 31 2c 30 2c 30 2c 30 [...3 bytes]","is_illegal":false,"parts":[]}},"typehash":12098283485503622895}},"dest_port":{"actor_name":"log_forw[...26 chars] CRC:40ce5be2 6c 6f 67 5f 66 6f 72 77 [...18 bytes]","port":18039862042805291298},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:43.206016 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@e11FpMbH7Nv2KO0TnuzmvScm,anon_0_1sZcWdWgQgSB,comm_11zyPNv7fD2q[0][13147652568889606402<hyperactor_mesh::comm::multicast::CastMessage>], headers:hyperactor_mesh::actor_mesh::cast_actor_mesh_id=logger_1iJt2YtUQhLf,hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.472957445+00:00, data:CastMessage{"dest":{"selection":"True","slice":{"offset":0,"sizes":[1],"strides":[1]}},"message":{"actor_mesh_id":{"V1":{"Suffixed":"[\"logger[...30 chars] CRC:8f1d0802 5b 22 6c 6f 67 67 65 72 [...22 bytes]"}},"data":{"bindings":[],"message":{"encoded":{"Multipart":{"body":"[0,0,0,0[...12 chars] CRC:b564c5bf 5b 30 2c 30 2c 30 2c 30 [...4 bytes]","is_illegal":false,"parts":[]}},"typehash":10911722563623013595}},"dest_port":{"actor_name":"logger_1[...19 chars] CRC:df3b092a 6c 6f 67 67 65 72 5f 31 [...11 bytes]","port":10648924583654510167},"sender":"[{\"Direc[...86 chars] CRC:507af745 5b 7b 22 44 69 72 65 63 [...78 bytes]","shape":{"labels":"[\"hosts\"[...9 chars] CRC:52560197 5b 22 68 6f 73 74 73 22 [...1 bytes]","slice":{"offset":0,"sizes":[1],"strides":[1]}}}}
# [-]E1022 05:20:43.206069 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@e11FpMbH7Nv2KO0TnuzmvScm,anon_0_1sZcWdWgQgSB,agent[0][16476089041836231337<hyperactor_mesh::resource::GetRankStatus>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.257148762+00:00,hyperactor_mesh::comm::multicast::cast_point=hosts=0/1,hyperactor_mesh::comm::multicast::cast_originating_sender=unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], data:GetRankStatus{"name":{"Suffixed":"[\"comm\",[...27 chars] CRC:e7488678 5b 22 63 6f 6d 6d 22 2c [...19 bytes]"},"reply":{"phantom":null,"port_id":"[[{\"Dire[...93 chars] CRC:4175567e 5b 5b 7b 22 44 69 72 65 [...85 bytes]","reducer_opts":null,"reducer_spec":{"builder_params":null,"typehash":4493460774099310317}}}
# [-]E1022 05:20:43.206105 34449 hyperactor/src/mailbox.rs:782] message not delivered, , name:undelivered_message_abandoned, actor_name:client, actor_id:unix:@QfdlbCKGMtupCkSc9A1iqdP6,mesh_root_client_proc,client[0], dest:unix:@e11FpMbH7Nv2KO0TnuzmvScm,anon_0_1sZcWdWgQgSB,comm_11zyPNv7fD2q[0][9438540675267141827<hyperactor_mesh::comm::CommActorMode>], headers:hyperactor::mailbox::headers::send_timestamp=2025-10-22T05:20:12.367620540+00:00, data:CommActorMode{"Mesh":"[0,{\"0\":[...105 chars] CRC:a4ad744e 5b 30 2c 7b 22 30 22 3a [...97 bytes]"}
